# %%
import pandas as pd

# %%
df = pd.read_json('jobs_maio.json')

# %%
df=df[['title', 'job_web', 'job_data_post', 'compane_name', 'city', 'area', 'url', 'number_points', 'modal']]

# %%
df.to_excel(r'jobs.xlsx', index=False)

# %%
df
# Out:
#                                                  title   job_web
# 0                               Dealer (Jogos de mesa)      Pepe  \
# 1                                      Técnico Nível I  Concurso
# 2    Recrutamento de um Assistente Comercial - São ...   vagascv
# 3                                     AGENTE DE VIAGEM      Pepe
# 4                          Técnico de Finanças Nível I  Concurso
# ..                                                 ...       ...
# 98                                     Técnico Nível I  Concurso
# 99   Recrutamento de Técnico de Operações para Pró-...   vagascv
# 100  Recrutamento de um Técnico Eletromecânico - Praia   vagascv
# 101                        Técnico de Finanças Nível I  Concurso
# 102  Brennpunkt Logistik está a Contratar 10 pessoa...   vagascv
#
#                   job_data_post
# 0    {'days_from_epoch': 19474}  \
# 1    {'days_from_epoch': 19452}
# 2    {'days_from_epoch': 19483}
# 3    {'days_from_epoch': 19474}
# ...
