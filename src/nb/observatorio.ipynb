# %% [markdown]
# # Relatorio de oferta

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_json('jobs.json')

# %%
df.head()
# Out:
#                                      id
# 0  03574852-b53c-4f96-baaa-582a08f01e85  \
# 1  75cdf2d4-e2fb-442f-80bd-26afb3a8e6e6
# 2  569eaea4-f039-4e0e-b7be-1abfc92eb0a6
# 3  0ba88ef4-9f5f-4aef-a9ec-08e672d6495c
# 4  812f32e0-68c0-4ded-9ceb-43ffb707e668
#
#                                         company                createdAt
# 0               Embaixada dos EUA em Cabo Verde  2023-10-05 16:10:47.986  \
# 1        Ourivesaria Sofia Sociedade Unipessoal  2023-10-05 16:26:07.251
# 2  Instituto Internacional da Língua Portuguesa  2023-10-05 16:33:15.531
# 3                                     Salss Lda  2023-10-05 16:39:22.597
# 4                                 Hotel Central  2023-10-05 16:42:47.596
#
#    number_points                       city     modal           area
# 0              1                      Praia  Contrato      Aquisição  \
# 1              4                      Praia  Contrato    Atendimento
# 2              1                      Praia  Contrato  Administração
# ...

# %%
df = df.set_index('id')

# %%
df = df.drop(['createdAt', 'imagem', 'url', 'job_cod'], axis=1)

# %%
df['day']= pd.to_datetime(df['postedAt']).dt.date

# %%
df.head()
# Out:
#                                                                            company
# id
# 03574852-b53c-4f96-baaa-582a08f01e85               Embaixada dos EUA em Cabo Verde  \
# 75cdf2d4-e2fb-442f-80bd-26afb3a8e6e6        Ourivesaria Sofia Sociedade Unipessoal
# 569eaea4-f039-4e0e-b7be-1abfc92eb0a6  Instituto Internacional da Língua Portuguesa
# 0ba88ef4-9f5f-4aef-a9ec-08e672d6495c                                     Salss Lda
# 812f32e0-68c0-4ded-9ceb-43ffb707e668                                 Hotel Central
#
#                                       number_points
# id
# 03574852-b53c-4f96-baaa-582a08f01e85              1  \
# 75cdf2d4-e2fb-442f-80bd-26afb3a8e6e6              4
# 569eaea4-f039-4e0e-b7be-1abfc92eb0a6              1
# 0ba88ef4-9f5f-4aef-a9ec-08e672d6495c              1
# 812f32e0-68c0-4ded-9ceb-43ffb707e668              1
#
#                                                            city     modal
# id
# ...

# %%
df['limite']= pd.to_datetime(df['data_limit']).dt.date

# %%
df.head(10)
# Out:
#                                                                                 company
# id
# 03574852-b53c-4f96-baaa-582a08f01e85                    Embaixada dos EUA em Cabo Verde  \
# 75cdf2d4-e2fb-442f-80bd-26afb3a8e6e6             Ourivesaria Sofia Sociedade Unipessoal
# 569eaea4-f039-4e0e-b7be-1abfc92eb0a6       Instituto Internacional da Língua Portuguesa
# 0ba88ef4-9f5f-4aef-a9ec-08e672d6495c                                          Salss Lda
# 812f32e0-68c0-4ded-9ceb-43ffb707e668                                      Hotel Central
# 6cf6c269-095f-4af1-ac2d-8b3aaa064b7a                           Pão Quente de Cabo Verde
# 5cae0caf-1f62-4b8d-819b-e4b7bd62b8f6  Empresa de importação e distribuição de produt...
# caf5fe8b-3c0c-4670-8699-362c0b4205e4                Fundo Monetário Internacional (FMI)
# 2f7d0f5e-9fc5-476e-9133-7bea0655fb4f                                       Importex Lda
# 16fc2215-4835-4b60-8378-ffea4600996f                                        Grupo Socid
#
# ...

# %%
df = df.drop(['postedAt', 'data_limit'], axis=1)

# %%
df
# Out:
#                                                                            company
# id
# 03574852-b53c-4f96-baaa-582a08f01e85               Embaixada dos EUA em Cabo Verde  \
# 75cdf2d4-e2fb-442f-80bd-26afb3a8e6e6        Ourivesaria Sofia Sociedade Unipessoal
# 569eaea4-f039-4e0e-b7be-1abfc92eb0a6  Instituto Internacional da Língua Portuguesa
# 0ba88ef4-9f5f-4aef-a9ec-08e672d6495c                                     Salss Lda
# 812f32e0-68c0-4ded-9ceb-43ffb707e668                                 Hotel Central
# ...                                                                            ...
# 7f79a2ff-0472-45d3-b798-15982232cc6b                                    Distrimpor
# 74e0b7c4-e65c-4fab-a16b-22512ca6e14d                                  Kebra Cabana
# 19a51449-a9f0-4db4-8b16-8468356ee52b                     Cabo Verde Airports, S.A.
# a064a305-deb5-4f9b-9eff-ccf9f6cac68a                          BAFAS fast food Lda.
# ...

# %%
total_posto =df["number_points"].sum()
print(total_posto)
# Out:
# 105

# %%
total_oferta = df["title"].count
print(total_oferta)
# Out:
# <bound method Series.count of id
# 03574852-b53c-4f96-baaa-582a08f01e85         Supervisor de Aquisições
# 75cdf2d4-e2fb-442f-80bd-26afb3a8e6e6           Atendimento ao Cliente
# 569eaea4-f039-4e0e-b7be-1abfc92eb0a6               Secretaria do IILP
# 0ba88ef4-9f5f-4aef-a9ec-08e672d6495c              Comercial de Vendas
# 812f32e0-68c0-4ded-9ceb-43ffb707e668                        Camareira
#                                                     ...
# 7f79a2ff-0472-45d3-b798-15982232cc6b                        Comercial
# 74e0b7c4-e65c-4fab-a16b-22512ca6e14d                       Seguranças
# 19a51449-a9f0-4db4-8b16-8468356ee52b           Técnico de Informático
# a064a305-deb5-4f9b-9eff-ccf9f6cac68a    Funcionários para Restaurante
# fcfb73aa-c3b1-4c4d-802a-16c04e7164ab      Técnico de Recursos Humanos
# Name: title, Length: 80, dtype: object>

# %%
oferta_regiao = df[["city", "number_points"]].groupby("city").sum()
display(oferta_regiao)
# Out:
#                            number_points
# city
# Assomada                               1
# Boa Vista                              1
# Boavista                               1
# Norte Santiago                         1
# Praia                                 66
# Sal                                   12
# Santa Cruz - Santiago                  1
# Santa Maria - ilha do Sal              3
# Santiago                               3
# Santiago- Santa Catarina               2
# Santiago- São Miguel                   1
# Santiago-Santa Cruz                    2
# Santo Antão                            1
# São Nicolau                            1
# São Vicente                            7
# São Vicente/ Maio                      2

# %%
df.head(10)
# Out:
#                                                                                 company
# id
# 03574852-b53c-4f96-baaa-582a08f01e85                    Embaixada dos EUA em Cabo Verde  \
# 75cdf2d4-e2fb-442f-80bd-26afb3a8e6e6             Ourivesaria Sofia Sociedade Unipessoal
# 569eaea4-f039-4e0e-b7be-1abfc92eb0a6       Instituto Internacional da Língua Portuguesa
# 0ba88ef4-9f5f-4aef-a9ec-08e672d6495c                                          Salss Lda
# 812f32e0-68c0-4ded-9ceb-43ffb707e668                                      Hotel Central
# 6cf6c269-095f-4af1-ac2d-8b3aaa064b7a                           Pão Quente de Cabo Verde
# 5cae0caf-1f62-4b8d-819b-e4b7bd62b8f6  Empresa de importação e distribuição de produt...
# caf5fe8b-3c0c-4670-8699-362c0b4205e4                Fundo Monetário Internacional (FMI)
# 2f7d0f5e-9fc5-476e-9133-7bea0655fb4f                                       Importex Lda
# 16fc2215-4835-4b60-8378-ffea4600996f                                        Grupo Socid
#
# ...

# %%
oferta_regiao = df[["city", "number_points"]].groupby("city").sum()
display(oferta_regiao)
# Out:
#                            number_points
# city
# Assomada                               1
# Boa Vista                              1
# Boavista                               1
# Norte Santiago                         1
# Praia                                 66
# Sal                                   12
# Santa Cruz - Santiago                  1
# Santa Maria - ilha do Sal              3
# Santiago                               3
# Santiago- Santa Catarina               2
# Santiago- São Miguel                   1
# Santiago-Santa Cruz                    2
# Santo Antão                            1
# São Nicolau                            1
# São Vicente                            7
# São Vicente/ Maio                      2

# %%
df.head()
# Out:
#                                                                            company
# id
# 03574852-b53c-4f96-baaa-582a08f01e85               Embaixada dos EUA em Cabo Verde  \
# 75cdf2d4-e2fb-442f-80bd-26afb3a8e6e6        Ourivesaria Sofia Sociedade Unipessoal
# 569eaea4-f039-4e0e-b7be-1abfc92eb0a6  Instituto Internacional da Língua Portuguesa
# 0ba88ef4-9f5f-4aef-a9ec-08e672d6495c                                     Salss Lda
# 812f32e0-68c0-4ded-9ceb-43ffb707e668                                 Hotel Central
#
#                                       number_points
# id
# 03574852-b53c-4f96-baaa-582a08f01e85              1  \
# 75cdf2d4-e2fb-442f-80bd-26afb3a8e6e6              4
# 569eaea4-f039-4e0e-b7be-1abfc92eb0a6              1
# 0ba88ef4-9f5f-4aef-a9ec-08e672d6495c              1
# 812f32e0-68c0-4ded-9ceb-43ffb707e668              1
#
#                                                            city     modal
# id
# ...

# %%
df["city"].replace(to_replace=["Assomada", "Norte Santiago", "Santiago- Santa Catarina"], value="Santa Catarina", inplace=True)

# %%
df["city"].replace(to_replace=["São Vicente/ Maio", "Boavista", "Santa Maria - ilha do Sal", "Santiago-Santa Cruz", "Santiago- São Miguel", "Santiago", "Santa Cruz - Santiago"],
                     value=["São Vicente", "Boa Vista", "Sal", "Santa Cruz", "São Miguel", "Praia", "Santa Cruz"], inplace=True
                      )

# %%
df
# Out:
#                                                                            company
# id
# 03574852-b53c-4f96-baaa-582a08f01e85               Embaixada dos EUA em Cabo Verde  \
# 75cdf2d4-e2fb-442f-80bd-26afb3a8e6e6        Ourivesaria Sofia Sociedade Unipessoal
# 569eaea4-f039-4e0e-b7be-1abfc92eb0a6  Instituto Internacional da Língua Portuguesa
# 0ba88ef4-9f5f-4aef-a9ec-08e672d6495c                                     Salss Lda
# 812f32e0-68c0-4ded-9ceb-43ffb707e668                                 Hotel Central
# ...                                                                            ...
# 7f79a2ff-0472-45d3-b798-15982232cc6b                                    Distrimpor
# 74e0b7c4-e65c-4fab-a16b-22512ca6e14d                                  Kebra Cabana
# 19a51449-a9f0-4db4-8b16-8468356ee52b                     Cabo Verde Airports, S.A.
# a064a305-deb5-4f9b-9eff-ccf9f6cac68a                          BAFAS fast food Lda.
# ...

# %%
df.head(30)
# Out:
#                                                                                 company
# id
# 03574852-b53c-4f96-baaa-582a08f01e85                    Embaixada dos EUA em Cabo Verde  \
# 75cdf2d4-e2fb-442f-80bd-26afb3a8e6e6             Ourivesaria Sofia Sociedade Unipessoal
# 569eaea4-f039-4e0e-b7be-1abfc92eb0a6       Instituto Internacional da Língua Portuguesa
# 0ba88ef4-9f5f-4aef-a9ec-08e672d6495c                                          Salss Lda
# 812f32e0-68c0-4ded-9ceb-43ffb707e668                                      Hotel Central
# 6cf6c269-095f-4af1-ac2d-8b3aaa064b7a                           Pão Quente de Cabo Verde
# 5cae0caf-1f62-4b8d-819b-e4b7bd62b8f6  Empresa de importação e distribuição de produt...
# caf5fe8b-3c0c-4670-8699-362c0b4205e4                Fundo Monetário Internacional (FMI)
# 2f7d0f5e-9fc5-476e-9133-7bea0655fb4f                                       Importex Lda
# 16fc2215-4835-4b60-8378-ffea4600996f                                        Grupo Socid
#
# ...

# %%
#numero de posto por cidade
oferta_regiao = df[["city", "number_points"]].groupby("city").sum()
display(oferta_regiao)
# Out:
#                 number_points
# city
# Boa Vista                   2
# Praia                      69
# Sal                        15
# Santa Catarina              4
# Santa Cruz                  3
# Santo Antão                 1
# São Miguel                  1
# São Nicolau                 1
# São Vicente                 9

# %%
#conta o total de oferta(geral)
total_oferta = df["title"].count()
print(total_oferta)
# Out:
# 80

# %%
#Guardar dados em formato csv
#df.to_csv(r"caminho para armazenar o arquivo csv exportado\Nome do arquivo.csv")
df.to_csv(r"C:\Users\nito-\OneDrive\Documentos\observatorio.csv")

# %%
#conta o total de oferta(geral)
total_oferta = df["title"].count()
print(total_oferta)
# Out:
# 80

# %%
#df[df['day'].dt.month == 10] & [df['day'].dt.year == 2023]
out_nov= df.loc[(df['day'] == '2023-10-01') & (df['day'] =< '2023-11-30')]
# Out:
#   Cell In[26], line 2
#     out_nov= df.loc[(df['day'] == '2023-10-01') & (df['day'] =< '2023-11-30')]
#                                                              ^
# SyntaxError: invalid syntax

# %%
#filt = (df['day'] == '2023-10-01') & (df['day'] == '2023-10-31')
#print(filt

# %%
dt= df.query('day=="2023-10-03"')
dt
# Out:
#                                                                            company
# id
# 03574852-b53c-4f96-baaa-582a08f01e85               Embaixada dos EUA em Cabo Verde  \
# 569eaea4-f039-4e0e-b7be-1abfc92eb0a6  Instituto Internacional da Língua Portuguesa
#
#                                       number_points   city     modal
# id
# 03574852-b53c-4f96-baaa-582a08f01e85              1  Praia  Contrato  \
# 569eaea4-f039-4e0e-b7be-1abfc92eb0a6              1  Praia  Contrato
#
#                                                area   website
# id
# 03574852-b53c-4f96-baaa-582a08f01e85      Aquisição  vagas CV  \
# 569eaea4-f039-4e0e-b7be-1abfc92eb0a6  Administração  vagas CV
#
#                                                          title        day
# id
# 03574852-b53c-4f96-baaa-582a08f01e85  Supervisor de Aquisições 2023-10-03  \
# 569eaea4-f039-4e0e-b7be-1abfc92eb0a6        Secretaria do IILP 2023-10-03
#
#                                          limite
# id
# ...

# %%
#df['day']= df['day'].astype('date')

# %%
# comando que pega data num intervalo de dois meses
dt= df.loc[(df['day'] >= '2023-10-01') & (df['day'] <= '2023-11-30')]

dt
# Out:
#                                                                            company
# id
# 03574852-b53c-4f96-baaa-582a08f01e85               Embaixada dos EUA em Cabo Verde  \
# 569eaea4-f039-4e0e-b7be-1abfc92eb0a6  Instituto Internacional da Língua Portuguesa
# 2f7d0f5e-9fc5-476e-9133-7bea0655fb4f                                  Importex Lda
# 16fc2215-4835-4b60-8378-ffea4600996f                                   Grupo Socid
# 4317dc69-2360-43c4-9484-7404cd4d6cc4                                    Inforusado
# ...                                                                            ...
# 7f79a2ff-0472-45d3-b798-15982232cc6b                                    Distrimpor
# 74e0b7c4-e65c-4fab-a16b-22512ca6e14d                                  Kebra Cabana
# 19a51449-a9f0-4db4-8b16-8468356ee52b                     Cabo Verde Airports, S.A.
# a064a305-deb5-4f9b-9eff-ccf9f6cac68a                          BAFAS fast food Lda.
# ...

# %%
df= dt.to_csv('out.csv', encoding='utf-8', index=False)

# %%
varia= (df['day'] <= '2023-11-30').count()

# %%
varia
# Out:
# 80

# %% [markdown]
# varia= (df['day'] <= '2023-11-30').

# %%
dt['company'].count()
# Out:
# 67

# %%
#total de oferta mes de out_nov
dt['title'].count()
# Out:
# 67

# %%
#conta o total de oferta(out_nov)
total_oferta =(df.loc[(df['day'] >= '2023-10-01') & (df['day'] <= '2023-11-30')]),df["title"].count()

#print(total_oferta)

# %%
total_oferta
# Out:
# (                                                                           company
#  id
#  03574852-b53c-4f96-baaa-582a08f01e85               Embaixada dos EUA em Cabo Verde  \
#  569eaea4-f039-4e0e-b7be-1abfc92eb0a6  Instituto Internacional da Língua Portuguesa
#  2f7d0f5e-9fc5-476e-9133-7bea0655fb4f                                  Importex Lda
#  16fc2215-4835-4b60-8378-ffea4600996f                                   Grupo Socid
#  4317dc69-2360-43c4-9484-7404cd4d6cc4                                    Inforusado
#  ...                                                                            ...
#  7f79a2ff-0472-45d3-b798-15982232cc6b                                    Distrimpor
#  74e0b7c4-e65c-4fab-a16b-22512ca6e14d                                  Kebra Cabana
#  19a51449-a9f0-4db4-8b16-8468356ee52b                     Cabo Verde Airports, S.A.
#  a064a305-deb5-4f9b-9eff-ccf9f6cac68a                          BAFAS fast food Lda.
# ...

# %%
#out= df.loc[(df['day'] >= '2023-10-03') & (df['day'] <= '2023-10-31')]
out =(df.loc[(df['day'] >= '2023-10-01') & (df['day'] <= '2023-10-31')]),df["title"].count()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[129], line 2
#       1 #out= df.loc[(df['day'] >= '2023-10-03') & (df['day'] <= '2023-10-31')]
# ----> 2 out =(df.loc[(df['day'] >= '2023-10-01') & (df['day'] <= '2023-10-31')])
#
# AttributeError: 'NoneType' object has no attribute 'loc'

# %%
comp= df.loc((df['day'] <= '2023-11-30')) - (df['day'] >= '2023-10-01')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[144], line 1
# ----> 1 comp= df[loc((df['day'] <= '2023-11-30')) - (df['day'] >= '2023-10-01')]
#
# NameError: name 'loc' is not defined
